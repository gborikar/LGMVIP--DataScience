# %% [markdown]
# # Importing important libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Import & Explore dataset

# %%
df = pd.read_csv('globalterrorismdb_0718dist.csv', encoding='ISO-8859-1', low_memory=False)
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
df.shape
# Out:
# (181691, 135)

# %%
df.isna().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
df.nunique()
# Out:
# eventid       181691
# iyear             47
# imonth            13
# iday              32
# approxdate      2244
#                ...
# INT_LOG            3
# INT_IDEO           3
# INT_MISC           3
# INT_ANY            3
# related        14306
# Length: 135, dtype: int64

# %%
df.corr()
# Out:
# C:\Users\Gaurav.DESKTOP-IOPIP0E\AppData\Local\Temp\ipykernel_22264\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#             eventid     iyear    imonth      iday  extended   country  \
# eventid    1.000000  0.999996  0.002706  0.018336  0.091761 -0.135039
# iyear      0.999996  1.000000  0.000139  0.018254  0.091754 -0.135023
# imonth     0.002706  0.000139  1.000000  0.005497 -0.000468 -0.006305
# iday       0.018336  0.018254  0.005497  1.000000 -0.004700  0.003468
# extended   0.091761  0.091754 -0.000468 -0.004700  1.000000 -0.020466
# ...             ...       ...       ...       ...       ...       ...
# nreleased -0.181612 -0.181556 -0.011535  0.001765 -0.192155 -0.044331
# INT_LOG   -0.143600 -0.143601 -0.002302 -0.001540  0.071768  0.069904
# ...

# %% [markdown]
# # Plot graphs

# %%
# Plot the number of terrorist attacks by year
plt.figure(figsize=(15, 10))
sns.countplot(x='iyear', data=df)
plt.xticks(rotation=90)
plt.title('Number of Terrorist Attacks by Year')
plt.show()

# %%
# Plot the number of terrorist attacks by country
plt.figure(figsize=(15, 15))
sns.countplot(x='country_txt', data=df)
plt.xticks(rotation=90)
plt.title('Number of Terrorist Attacks by Country')
plt.show()

# %%
df['country_txt'].value_counts().head(25)
# Out:
# Iraq                        24636
# Pakistan                    14368
# Afghanistan                 12731
# India                       11960
# Colombia                     8306
# Philippines                  6908
# Peru                         6096
# El Salvador                  5320
# United Kingdom               5235
# Turkey                       4292
# Somalia                      4142
# Nigeria                      3907
# Thailand                     3849
# Yemen                        3347
# Spain                        3249
# Sri Lanka                    3022
# United States                2836
# Algeria                      2743
# France                       2693
# Egypt                        2479
# Lebanon                      2478
# Chile                        2365
# Libya                        2249
# West Bank and Gaza Strip     2227
# Syria                        2201
# Name: country_txt, dtype: int64

# %%
# Plot the number of terrorist attacks by TOP 25 countries
plt.figure(figsize=(15, 15))
sns.countplot(x='country_txt', data=df, order=df['country_txt'].value_counts().head(25).index)
plt.xticks(rotation=90)
plt.title('Number of Terrorist Attacks by Country (TOP 25)')
plt.show()

# %%
# Plot the number of terrorist attacks by region
plt.figure(figsize=(15, 10))
sns.countplot(x='region_txt', data=df)
plt.xticks(rotation=90)
plt.title('Number of Terrorist Attacks by Region')
plt.show()

# %%
df['nkill'].fillna(df['nkill'].mean(), inplace = True)

# %%
# Plot the number of deaths by year
plt.figure(figsize=(15, 10))
sns.barplot(x='iyear', y='nkill', data=df, estimator=np.sum)
plt.xticks(rotation=90)
plt.title('Number of Deaths by Year')
plt.show()

# %%
# Plot the number of deaths by country
plt.figure(figsize=(15, 10))
sns.barplot(x='country_txt', y='nkill', data=df, estimator=np.sum)
plt.xticks(rotation=90)
plt.title('Number of Deaths by Country')
plt.show()

# %%
df['nkill'].value_counts().head(25).values
# Out:
# array([88149, 36576, 14147, 10313,  7738,  4961,  3565,  2552,  1960,
#         1495,  1192,  1054,   833,   747,   575,   556,   487,   402,
#          372,   316,   313,   214,   209,   199,   194], dtype=int64)

# %%
# Plot the number of deaths by country for TOP 25 countries
plt.figure(figsize=(15, 10))
sns.barplot(x='country_txt', y='nkill', data=df.groupby('country_txt')['nkill'].sum().reset_index().sort_values(by='nkill', ascending=False).head(25))
plt.xticks(rotation=90)
plt.title('Number of Deaths by Country (TOP 25)')
plt.show()

# %%
# Plot the number of deaths by region
plt.figure(figsize=(15, 10))
sns.barplot(x='region_txt', y='nkill', data=df, estimator=np.sum)
plt.xticks(rotation=90)
plt.title('Number of Deaths by Region')
plt.show()

# %%
# Plot the number of deaths by weapons
plt.figure(figsize=(15, 10))
sns.countplot(x='weaptype1_txt',data=df ,order = df['weaptype1_txt'].value_counts().index)
plt.xticks(rotation=90)
plt.title('Number of Deaths by Weapon Types')
plt.show()

# %%
plt.figure(figsize=(15, 10))
sns.countplot(x='attacktype1_txt',data=df ,order = df['attacktype1_txt'].value_counts().index)
plt.xticks(rotation=90)
plt.title('Number of Deaths by Attack Types')
plt.show()

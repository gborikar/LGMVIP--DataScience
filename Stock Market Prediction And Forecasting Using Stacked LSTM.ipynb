# %%
#https://raw.githubusercontent.com/mwitiderrick/stockprice/master/NSE-TATAGLOBAL.csv

# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Dense

# %%
stock = pd.read_csv('https://raw.githubusercontent.com/mwitiderrick/stockprice/master/NSE-TATAGLOBAL.csv', index_col = 0)

# %%
stock.head()
# Out:
#               Open    High     Low    Last   Close  Total Trade Quantity  \
# Date
# 2018-09-28  234.05  235.95  230.20  233.50  233.75               3069914
# 2018-09-27  234.55  236.80  231.10  233.80  233.25               5082859
# 2018-09-26  240.00  240.00  232.50  235.00  234.25               2240909
# 2018-09-25  233.30  236.75  232.00  236.25  236.10               2349368
# 2018-09-24  233.55  239.20  230.75  234.00  233.30               3423509
#
#             Turnover (Lacs)
# Date
# 2018-09-28          7162.35
# 2018-09-27         11859.95
# 2018-09-26          5248.60
# 2018-09-25          5503.90
# 2018-09-24          7999.55

# %%
stock.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2035 entries, 2018-09-28 to 2010-07-21
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Open                  2035 non-null   float64
#  1   High                  2035 non-null   float64
#  2   Low                   2035 non-null   float64
#  3   Last                  2035 non-null   float64
#  4   Close                 2035 non-null   float64
#  5   Total Trade Quantity  2035 non-null   int64
#  6   Turnover (Lacs)       2035 non-null   float64
# dtypes: float64(6), int64(1)
# memory usage: 127.2+ KB

# %%
stock.shape
# Out:
# (2035, 7)

# %%
stock.describe()
# Out:
#               Open         High          Low         Last       Close  \
# count  2035.000000  2035.000000  2035.000000  2035.000000  2035.00000
# mean    149.713735   151.992826   147.293931   149.474251   149.45027
# std      48.664509    49.413109    47.931958    48.732570    48.71204
# min      81.100000    82.800000    80.000000    81.000000    80.95000
# 25%     120.025000   122.100000   118.300000   120.075000   120.05000
# 50%     141.500000   143.400000   139.600000   141.100000   141.25000
# 75%     157.175000   159.400000   155.150000   156.925000   156.90000
# max     327.700000   328.750000   321.650000   325.950000   325.75000
#
#        Total Trade Quantity  Turnover (Lacs)
# count          2.035000e+03      2035.000000
# mean           2.335681e+06      3899.980565
# std            2.091778e+06      4570.767877
# min            3.961000e+04        37.040000
# 25%            1.146444e+06      1427.460000
# 50%            1.783456e+06      2512.030000
# 75%            2.813594e+06      4539.015000
# max            2.919102e+07     55755.080000

# %% [markdown]
# ## Check outliers

# %%
plt.boxplot(stock[['Open', 'High', 'Low', 'Last', 'Close']])
plt.show()

# %%
stock['Close'].plot(figsize = (15,6))
plt.ylabel('Price')
plt.show()

# %% [markdown]
# ## Train Test Split

# %%
training_stock = stock.iloc[:int(len(stock)*0.75), ]
testing_stock = stock.iloc[int(len(stock)*0.75):, ]

# %%
training_stock.shape
# Out:
# (1526, 7)

# %%
testing_stock.shape
# Out:
# (509, 7)

# %%
training_stock.head()
# Out:
#               Open    High     Low    Last   Close  Total Trade Quantity  \
# Date
# 2018-09-28  234.05  235.95  230.20  233.50  233.75               3069914
# 2018-09-27  234.55  236.80  231.10  233.80  233.25               5082859
# 2018-09-26  240.00  240.00  232.50  235.00  234.25               2240909
# 2018-09-25  233.30  236.75  232.00  236.25  236.10               2349368
# 2018-09-24  233.55  239.20  230.75  234.00  233.30               3423509
#
#             Turnover (Lacs)
# Date
# 2018-09-28          7162.35
# 2018-09-27         11859.95
# 2018-09-26          5248.60
# 2018-09-25          5503.90
# 2018-09-24          7999.55

# %%
training_stock.iloc[:,4:5]
# Out:
#              Close
# Date
# 2018-09-28  233.75
# 2018-09-27  233.25
# 2018-09-26  234.25
# 2018-09-25  236.10
# 2018-09-24  233.30
# ...            ...
# 2012-08-03  131.15
# 2012-08-02  130.05
# 2012-08-01  127.05
# 2012-07-31  127.00
# 2012-07-30  122.65
#
# [1526 rows x 1 columns]

# %%
training_data = training_stock.iloc[:,4:5].values
training_data
# Out:
# array([[233.75],
#        [233.25],
#        [234.25],
#        ...,
#        [127.05],
#        [127.  ],
#        [122.65]])

# %%
training_data.shape
# Out:
# (1526, 1)

# %% [markdown]
# ## Data Scaling

# %%
scaler=MinMaxScaler(feature_range=(0,1))
scaled_training_data = scaler.fit_transform(training_data)

# %%
scaled_training_data
# Out:
# array([[0.58762887],
#        [0.58538772],
#        [0.58987001],
#        ...,
#        [0.109368  ],
#        [0.10914388],
#        [0.0896459 ]])

# %% [markdown]
# ## LSTM Implementation

# %%
x_train=[]
y_train=[]
for i in range(60,len(training_data)):
    x_train.append(scaled_training_data[i-60:i,0])
    y_train.append(scaled_training_data[i, 0])
x_train,y_train=np.array(x_train),np.array(y_train)

# %%
# Reshape to fit into LSTM
x_train=x_train.reshape(x_train.shape[0],x_train.shape[1],1)

# %%
#Initiate the Model
lstm=Sequential([
    LSTM(60,return_sequences=True,input_shape=(x_train.shape[1],1)),
    Dropout(0.3),
    LSTM(60,return_sequences=True),
    Dropout(0.3),
    LSTM(60,return_sequences=True),
    Dropout(0.3),
    LSTM(60,return_sequences=True),
    Dropout(0.3),
    LSTM(60,return_sequences=False),
    Dropout(0.3),
    Dense(1)
])

# %%
#Compile the Model
lstm.compile(optimizer='adam',loss='mean_squared_error')

# %%
# Fit the Model
lstm.fit(x_train,y_train,epochs=100,batch_size=64)
# Out:
# Epoch 1/100
# 23/23 [==============================] - 14s 202ms/step - loss: 0.0213
# Epoch 2/100
# 23/23 [==============================] - 4s 180ms/step - loss: 0.0057
# Epoch 3/100
# 23/23 [==============================] - 4s 178ms/step - loss: 0.0052
# Epoch 4/100
# 23/23 [==============================] - 4s 175ms/step - loss: 0.0044
# Epoch 5/100
# 23/23 [==============================] - 4s 173ms/step - loss: 0.0040
# Epoch 6/100
# 23/23 [==============================] - 4s 173ms/step - loss: 0.0045
# Epoch 7/100
# 23/23 [==============================] - 4s 173ms/step - loss: 0.0039
# Epoch 8/100
# 23/23 [==============================] - 4s 174ms/step - loss: 0.0040
# Epoch 9/100
# 23/23 [==============================] - 4s 172ms/step - loss: 0.0034
# Epoch 10/100
# 23/23 [==============================] - 4s 173ms/step - loss: 0.0032
# Epoch 11/100
# 23/23 [==============================] - 4s 182ms/step - loss: 0.0037
# Epoch 12/100
# 23/23 [==============================] - 4s 187ms/step - loss: 0.0031
# Epoch 13/100
# 23/23 [==============================] - 4s 186ms/step - loss: 0.0036
# Epoch 14/100
# 23/23 [==============================] - 4s 184ms/step - loss: 0.0033
# Epoch 15/100
# 23/23 [==============================] - 4s 186ms/step - loss: 0.0030
# Epoch 16/100
# 23/23 [==============================] - 4s 185ms/step - loss: 0.0029
# Epoch 17/100
# 23/23 [==============================] - 4s 186ms/step - loss: 0.0032
# Epoch 18/100
# 23/23 [==============================] - 4s 186ms/step - loss: 0.0034
# Epoch 19/100
# 23/23 [==============================] - 4s 183ms/step - loss: 0.0029
# Epoch 20/100
# 23/23 [==============================] - 4s 185ms/step - loss: 0.0029
# Epoch 21/100
# 23/23 [==============================] - 4s 185ms/step - loss: 0.0028
# Epoch 22/100
# 23/23 [==============================] - 4s 185ms/step - loss: 0.0027
# Epoch 23/100
# 23/23 [==============================] - 4s 184ms/step - loss: 0.0027
# Epoch 24/100
# 23/23 [==============================] - 4s 185ms/step - loss: 0.0028
# Epoch 25/100
# 23/23 [==============================] - 4s 187ms/step - loss: 0.0028
# Epoch 26/100
# 23/23 [==============================] - 4s 186ms/step - loss: 0.0023
# Epoch 27/100
# 23/23 [==============================] - 4s 185ms/step - loss: 0.0026
# Epoch 28/100
# 23/23 [==============================] - 4s 185ms/step - loss: 0.0028
# Epoch 29/100
# 23/23 [==============================] - 4s 183ms/step - loss: 0.0023
# Epoch 30/100
# 23/23 [==============================] - 4s 185ms/step - loss: 0.0023
# Epoch 31/100
# 23/23 [==============================] - 4s 185ms/step - loss: 0.0031
# Epoch 32/100
# 23/23 [==============================] - 4s 184ms/step - loss: 0.0025
# Epoch 33/100
# 23/23 [==============================] - 4s 186ms/step - loss: 0.0023
# Epoch 34/100
# 23/23 [==============================] - 4s 185ms/step - loss: 0.0022
# Epoch 35/100
# 23/23 [==============================] - 4s 184ms/step - loss: 0.0020
# Epoch 36/100
# 23/23 [==============================] - 4s 186ms/step - loss: 0.0021
# Epoch 37/100
# 23/23 [==============================] - 4s 186ms/step - loss: 0.0022
# Epoch 38/100
# 23/23 [==============================] - 4s 188ms/step - loss: 0.0021
# Epoch 39/100
# 23/23 [==============================] - 4s 187ms/step - loss: 0.0020
# Epoch 40/100
# 23/23 [==============================] - 4s 189ms/step - loss: 0.0023
# Epoch 41/100
# 23/23 [==============================] - 4s 187ms/step - loss: 0.0020
# Epoch 42/100
# 23/23 [==============================] - 5s 199ms/step - loss: 0.0024
# Epoch 43/100
# 23/23 [==============================] - 5s 197ms/step - loss: 0.0021
# Epoch 44/100
# 23/23 [==============================] - 4s 195ms/step - loss: 0.0022
# Epoch 45/100
# 23/23 [==============================] - 4s 196ms/step - loss: 0.0019
# Epoch 46/100
# 23/23 [==============================] - 5s 200ms/step - loss: 0.0020
# Epoch 47/100
# 23/23 [==============================] - 5s 200ms/step - loss: 0.0020
# Epoch 48/100
# 23/23 [==============================] - 5s 196ms/step - loss: 0.0017
# Epoch 49/100
# 23/23 [==============================] - 5s 202ms/step - loss: 0.0021
# Epoch 50/100
# 23/23 [==============================] - 4s 195ms/step - loss: 0.0017
# Epoch 51/100
# 23/23 [==============================] - 4s 192ms/step - loss: 0.0020
# Epoch 52/100
# 23/23 [==============================] - 5s 218ms/step - loss: 0.0017
# Epoch 53/100
# 23/23 [==============================] - 4s 191ms/step - loss: 0.0020
# Epoch 54/100
# 23/23 [==============================] - 5s 200ms/step - loss: 0.0016
# Epoch 55/100
# 23/23 [==============================] - 5s 198ms/step - loss: 0.0019
# Epoch 56/100
# 23/23 [==============================] - 4s 193ms/step - loss: 0.0019
# Epoch 57/100
# 23/23 [==============================] - 5s 196ms/step - loss: 0.0016
# Epoch 58/100
# 23/23 [==============================] - 4s 195ms/step - loss: 0.0018
# Epoch 59/100
# 23/23 [==============================] - 4s 192ms/step - loss: 0.0019
# Epoch 60/100
# 23/23 [==============================] - 5s 199ms/step - loss: 0.0018
# Epoch 61/100
# 23/23 [==============================] - 4s 191ms/step - loss: 0.0017
# Epoch 62/100
# 23/23 [==============================] - 4s 193ms/step - loss: 0.0015
# Epoch 63/100
# 23/23 [==============================] - 5s 205ms/step - loss: 0.0016
# Epoch 64/100
# 23/23 [==============================] - 5s 195ms/step - loss: 0.0018
# Epoch 65/100
# 23/23 [==============================] - 4s 188ms/step - loss: 0.0015
# Epoch 66/100
# 23/23 [==============================] - 5s 199ms/step - loss: 0.0015
# Epoch 67/100
# 23/23 [==============================] - 5s 200ms/step - loss: 0.0018
# Epoch 68/100
# 23/23 [==============================] - 5s 196ms/step - loss: 0.0016
# Epoch 69/100
# 23/23 [==============================] - 4s 189ms/step - loss: 0.0016
# Epoch 70/100
# 23/23 [==============================] - 4s 188ms/step - loss: 0.0016
# Epoch 71/100
# 23/23 [==============================] - 4s 191ms/step - loss: 0.0015
# Epoch 72/100
# 23/23 [==============================] - 5s 206ms/step - loss: 0.0014
# Epoch 73/100
# 23/23 [==============================] - 4s 195ms/step - loss: 0.0014
# Epoch 74/100
# 23/23 [==============================] - 4s 194ms/step - loss: 0.0016
# Epoch 75/100
# 23/23 [==============================] - 4s 195ms/step - loss: 0.0015
# Epoch 76/100
# 23/23 [==============================] - 5s 211ms/step - loss: 0.0016
# Epoch 77/100
# 23/23 [==============================] - 5s 204ms/step - loss: 0.0015
# Epoch 78/100
# 23/23 [==============================] - 4s 188ms/step - loss: 0.0014
# Epoch 79/100
# 23/23 [==============================] - 5s 197ms/step - loss: 0.0015
# Epoch 80/100
# 23/23 [==============================] - 4s 190ms/step - loss: 0.0013
# Epoch 81/100
# 23/23 [==============================] - 5s 197ms/step - loss: 0.0012
# Epoch 82/100
# 23/23 [==============================] - 4s 193ms/step - loss: 0.0014
# Epoch 83/100
# 23/23 [==============================] - 4s 192ms/step - loss: 0.0014
# Epoch 84/100
# 23/23 [==============================] - 4s 191ms/step - loss: 0.0014
# Epoch 85/100
# 23/23 [==============================] - 4s 192ms/step - loss: 0.0014
# Epoch 86/100
# 23/23 [==============================] - 4s 192ms/step - loss: 0.0013
# Epoch 87/100
# 23/23 [==============================] - 4s 189ms/step - loss: 0.0013
# Epoch 88/100
# 23/23 [==============================] - 4s 192ms/step - loss: 0.0015
# Epoch 89/100
# 23/23 [==============================] - 4s 191ms/step - loss: 0.0012
# Epoch 90/100
# 23/23 [==============================] - 4s 191ms/step - loss: 0.0013
# Epoch 91/100
# 23/23 [==============================] - 4s 192ms/step - loss: 0.0014
# Epoch 92/100
# 23/23 [==============================] - 4s 192ms/step - loss: 0.0013
# Epoch 93/100
# 23/23 [==============================] - 4s 190ms/step - loss: 0.0013
# Epoch 94/100
# 23/23 [==============================] - 4s 192ms/step - loss: 0.0013
# Epoch 95/100
# 23/23 [==============================] - 4s 187ms/step - loss: 0.0015
# Epoch 96/100
# 23/23 [==============================] - 4s 195ms/step - loss: 0.0012
# Epoch 97/100
# 23/23 [==============================] - 4s 189ms/step - loss: 0.0013
# Epoch 98/100
# 23/23 [==============================] - 5s 200ms/step - loss: 0.0012
# Epoch 99/100
# 23/23 [==============================] - 4s 191ms/step - loss: 0.0013
# Epoch 100/100
# 23/23 [==============================] - 4s 189ms/step - loss: 0.0013

# %%
final_data =pd.concat((training_stock['Close'],testing_stock['Close']),axis=0)

# %%
inputs=final_data[len(final_data)-len(testing_stock)-60:].values
inputs=inputs.reshape(-1,1)
inputs=scaler.transform(inputs)

# %%
x_test=[]
for i in range(60,569):
    x_test.append(inputs[i-60:i, 0])
x_test=np.array(x_test)

# %%
x_test=x_test.reshape(x_test.shape[0],x_test.shape[1],1)

# %%
predicted_stock_price=lstm.predict(x_test)
# Out:
# 16/16 [==============================] - 3s 42ms/step

# %%
predicted_stock_price=scaler.inverse_transform(predicted_stock_price)

# %%
testing_stock['Predicted']=predicted_stock_price
# Out:
# C:\Users\Gaurav.DESKTOP-IOPIP0E\AppData\Local\Temp\ipykernel_9752\3526848106.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   testing_stock['Predicted']=predicted_stock_price

# %%
final_visualization=pd.concat([stock['Close'],testing_stock['Close'],testing_stock['Predicted']],axis=1)

# %%
final_visualization.plot(figsize=(15,5))
final_visualization.columns=['Training Data','Testing Data','Predicted']

# %%
plt.figure(figsize=(15,5))
testing_stock['Close'].plot(label='Actual')
testing_stock['Predicted'].plot(label='Predicted')
plt.legend()
plt.show()

# %%
Actual=testing_stock['Close']
Predicted=testing_stock['Predicted']
Difference = Predicted - Actual

# %%
Dataframe=pd.DataFrame({'Actual':Actual,'Predicted':Predicted, 'Difference':Difference})
Dataframe
# Out:
#             Actual   Predicted  Difference
# Date
# 2012-07-27  120.65  127.931076    7.281076
# 2012-07-26  120.05  125.676903    5.626903
# 2012-07-25  120.80  123.204880    2.404880
# 2012-07-24  123.40  121.348160   -2.051840
# 2012-07-23  115.65  120.869400    5.219400
# ...            ...         ...         ...
# 2010-07-27  118.65  118.590477   -0.059523
# 2010-07-26  117.60  118.528831    0.928831
# 2010-07-23  120.65  118.635361   -2.014639
# 2010-07-22  120.90  119.105034   -1.794966
# 2010-07-21  121.55  119.949501   -1.600499
#
# [509 rows x 3 columns]
